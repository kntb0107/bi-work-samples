# %% [markdown]
# <a href="https://colab.research.google.com/github/kntb0107/bi-work-samples/blob/main/PowerBI_Work_Samples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PowerBI Work Samples
#
# ###The following examples are from my latest work experience, where dashboards were made to meet client expectations.
#
# Please note that these dashboard's original data has been redacted in compliance to NDAs.

# %% [markdown]
# ## SAMPLE CRM DASHBOARD

# %%
from IPython.display import Image

# Display the image
Image(filename='/content/drive/MyDrive/work samples/CRM Sample Dashboard - Wireframe.png')

# %% [markdown]
# As per client's business requirement, this dashboard was developed to serve as a tool for translating Electronic Direct Mails (EDMs) into actinable insights the upper management can take appropriate business decisions on.
#
# **Requirement**
# It provides a visual representation of changes in customer interest following an EDM campaign, which can be broken down MOM. Insights are derived as well, allowing the stakeholders to be able to get quick top-line insights while viewing the report.

# %%
from IPython.display import Image

# Display the image
Image(filename='/content/drive/MyDrive/work samples/SAMPLE SOCIAL COMPETITIVE ANALYTICS DASHBOARD.png')

# %% [markdown]
#  This dashbaord enables a side-by-side comparison of the client's social media performance with that of their competitors. Key features include and can be derived from the dashboard are competitor performance comparison, key performance indicators (KPIs) monitoring, trend analysis, audience insights, content analysis, benchmarking. This particular dashboard was automated at a daily interval, making sure that the numbers were always up to date.
